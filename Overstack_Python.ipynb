# %%
#Import the data 
#1 Questions
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
from scipy.stats import norm
questions_python = pd.read_csv("Resources/Questions.csv", encoding = "ISO 8859-1")
questions_python.head()
# Out:
#     Id  OwnerUserId          CreationDate  Score  \
# 0  469        147.0  2008-08-02T15:11:16Z     21
# 1  502        147.0  2008-08-02T17:01:58Z     27
# 2  535        154.0  2008-08-02T18:43:54Z     40
# 3  594        116.0  2008-08-03T01:15:08Z     25
# 4  683        199.0  2008-08-03T13:19:16Z     28
#
#                                                Title  \
# 0  How can I find the full path to a font from it...
# 1            Get a preview JPEG of a PDF on Windows?
# 2  Continuous Integration System for a Python Cod...
# 3     cx_Oracle: How do I iterate over a result set?
# 4  Using 'in' to match an attribute of Python obj...
#
#                                                 Body
# 0  <p>I am using the Photoshop's javascript API t...
# 1  <p>I have a cross-platform (Python) applicatio...
# 2  <p>I'm starting work on a hobby project with a...
# 3  <p>There are several ways to iterate over a re...
# 4  <p>I don't remember whether I was dreaming or ...

# %%
#Sort Questions 
sort_questions = questions_python.sort_values(ascending=True, by = 'Id')
sort_questions.head()
# Out:
#     Id  OwnerUserId          CreationDate  Score  \
# 0  469        147.0  2008-08-02T15:11:16Z     21
# 1  502        147.0  2008-08-02T17:01:58Z     27
# 2  535        154.0  2008-08-02T18:43:54Z     40
# 3  594        116.0  2008-08-03T01:15:08Z     25
# 4  683        199.0  2008-08-03T13:19:16Z     28
#
#                                                Title  \
# 0  How can I find the full path to a font from it...
# 1            Get a preview JPEG of a PDF on Windows?
# 2  Continuous Integration System for a Python Cod...
# 3     cx_Oracle: How do I iterate over a result set?
# 4  Using 'in' to match an attribute of Python obj...
#
#                                                 Body
# 0  <p>I am using the Photoshop's javascript API t...
# 1  <p>I have a cross-platform (Python) applicatio...
# 2  <p>I'm starting work on a hobby project with a...
# 3  <p>There are several ways to iterate over a re...
# 4  <p>I don't remember whether I was dreaming or ...

# %%
#2 Ansers Python 
answers_python = pd.read_csv("Resources/Answers.csv", encoding = 'ISO 8859-1')
answers_python.head()
# Out:
#     Id  OwnerUserId          CreationDate  ParentId  Score  \
# 0  497         50.0  2008-08-02T16:56:53Z       469      4
# 1  518        153.0  2008-08-02T17:42:28Z       469      2
# 2  536        161.0  2008-08-02T18:49:07Z       502      9
# 3  538        156.0  2008-08-02T18:56:56Z       535     23
# 4  541        157.0  2008-08-02T19:06:40Z       535     20
#
#                                                 Body
# 0  <p>open up a terminal (Applications-&gt;Utilit...
# 1  <p>I haven't been able to find anything that d...
# 2  <p>You can use ImageMagick's convert utility f...
# 3  <p>One possibility is Hudson.  It's written in...
# 4  <p>We run <a href="http://buildbot.net/trac">B...

# %%
sort_answers = answers_python.sort_values(ascending=True, by = 'Id')
sort_answers.head()
# Out:
#     Id  OwnerUserId          CreationDate  ParentId  Score  \
# 0  497         50.0  2008-08-02T16:56:53Z       469      4
# 1  518        153.0  2008-08-02T17:42:28Z       469      2
# 2  536        161.0  2008-08-02T18:49:07Z       502      9
# 3  538        156.0  2008-08-02T18:56:56Z       535     23
# 4  541        157.0  2008-08-02T19:06:40Z       535     20
#
#                                                 Body
# 0  <p>open up a terminal (Applications-&gt;Utilit...
# 1  <p>I haven't been able to find anything that d...
# 2  <p>You can use ImageMagick's convert utility f...
# 3  <p>One possibility is Hudson.  It's written in...
# 4  <p>We run <a href="http://buildbot.net/trac">B...

# %%
#3 Tags Python 
tags_python = pd.read_csv("Resources/Tags.csv", encoding = 'ISO 8859-1')
tags_python.head()
# Out:
#     Id        Tag
# 0  469     python
# 1  469        osx
# 2  469      fonts
# 3  469  photoshop
# 4  502     python

# %%
#parse the date, then groupby and mean 
#pd.to_datetime[df[date]]
#group them into years

# %%
#Convert date into numerical value 
questions_python['CreationDate'] = pd.to_datetime(questions_python['CreationDate'])

# %%
answers_python['CreationDate'] = pd.to_datetime(answers_python['CreationDate'])

# %%
questions_python.dtypes
questions_python.head()
# Out:
#     Id  OwnerUserId        CreationDate  Score  \
# 0  469        147.0 2008-08-02 15:11:16     21
# 1  502        147.0 2008-08-02 17:01:58     27
# 2  535        154.0 2008-08-02 18:43:54     40
# 3  594        116.0 2008-08-03 01:15:08     25
# 4  683        199.0 2008-08-03 13:19:16     28
#
#                                                Title  \
# 0  How can I find the full path to a font from it...
# 1            Get a preview JPEG of a PDF on Windows?
# 2  Continuous Integration System for a Python Cod...
# 3     cx_Oracle: How do I iterate over a result set?
# 4  Using 'in' to match an attribute of Python obj...
#
#                                                 Body
# 0  <p>I am using the Photoshop's javascript API t...
# 1  <p>I have a cross-platform (Python) applicatio...
# 2  <p>I'm starting work on a hobby project with a...
# 3  <p>There are several ways to iterate over a re...
# 4  <p>I don't remember whether I was dreaming or ...

# %%
#Merge then calculate 
python_questions_2 = sort_questions.rename(columns={'CreationDate': 'CreationQuestionsDate'})
python_questions_2.head()
# Out:
#     Id  OwnerUserId CreationQuestionsDate  Score  \
# 0  469        147.0  2008-08-02T15:11:16Z     21
# 1  502        147.0  2008-08-02T17:01:58Z     27
# 2  535        154.0  2008-08-02T18:43:54Z     40
# 3  594        116.0  2008-08-03T01:15:08Z     25
# 4  683        199.0  2008-08-03T13:19:16Z     28
#
#                                                Title  \
# 0  How can I find the full path to a font from it...
# 1            Get a preview JPEG of a PDF on Windows?
# 2  Continuous Integration System for a Python Cod...
# 3     cx_Oracle: How do I iterate over a result set?
# 4  Using 'in' to match an attribute of Python obj...
#
#                                                 Body
# 0  <p>I am using the Photoshop's javascript API t...
# 1  <p>I have a cross-platform (Python) applicatio...
# 2  <p>I'm starting work on a hobby project with a...
# 3  <p>There are several ways to iterate over a re...
# 4  <p>I don't remember whether I was dreaming or ...

# %%
#merge_data = pd.merge(answers_python, questions_python, on = '')
#merge_data
sort_answers['Body'].unique().shape
# Out:
# (986883,)

# %%
print(sort_answers.shape)
print(sort_answers['Id'].unique().shape)
# Out:
# (987122, 6)
# (987122,)

# %%
sort_questions['Id'].min()
# Out:
# 469

# %%
#to find library
answer_pandas = sort_answers.loc[sort_answers['Body'].str.contains("pandas"), :]

# %%
answer_pandas.shape
# Out:
# (19945, 6)

# %%
answer_matplotlib = sort_answers.loc[sort_answers['Body'].str.contains("matplotlib"), :]

# %%
answer_matplotlib.shape
# Out:
# (15131, 6)

# %%
#Merge answers and questions 
#merge_answers_questions = answers_python.join(questions_python)
merge = sort_answers.merge(sort_questions, left_on = 'ParentId', right_on = 'Id', suffixes = ['_Answers' , '_Questions'])
merge.head()

#questions_python.dtypes
# Out:
#    Id_Answers  OwnerUserId_Answers  CreationDate_Answers  ParentId  \
# 0         497                 50.0  2008-08-02T16:56:53Z       469
# 1         518                153.0  2008-08-02T17:42:28Z       469
# 2        3040                457.0  2008-08-06T03:01:23Z       469
# 3      195170                745.0  2008-10-12T07:02:40Z       469
# 4         536                161.0  2008-08-02T18:49:07Z       502
#
#    Score_Answers                                       Body_Answers  \
# 0              4  <p>open up a terminal (Applications-&gt;Utilit...
# 1              2  <p>I haven't been able to find anything that d...
# 2             12  <p>Unfortunately the only API that isn't depre...
# 3              1  <p>There must be a method in Cocoa to get a li...
# 4              9  <p>You can use ImageMagick's convert utility f...
#
#    Id_Questions  OwnerUserId_Questions CreationDate_Questions  \
# 0           469                  147.0   2008-08-02T15:11:16Z
# 1           469                  147.0   2008-08-02T15:11:16Z
# 2           469                  147.0   2008-08-02T15:11:16Z
# 3           469                  147.0   2008-08-02T15:11:16Z
# 4           502                  147.0   2008-08-02T17:01:58Z
#
#    Score_Questions                                              Title  \
# 0               21  How can I find the full path to a font from it...
# 1               21  How can I find the full path to a font from it...
# 2               21  How can I find the full path to a font from it...
# 3               21  How can I find the full path to a font from it...
# 4               27            Get a preview JPEG of a PDF on Windows?
#
#                                       Body_Questions
# 0  <p>I am using the Photoshop's javascript API t...
# 1  <p>I am using the Photoshop's javascript API t...
# 2  <p>I am using the Photoshop's javascript API t...
# 3  <p>I am using the Photoshop's javascript API t...
# 4  <p>I have a cross-platform (Python) applicatio...

# %%
merge['CreationDate_Questions'] = pd.to_datetime(merge['CreationDate_Questions'])
merge['CreationDate_Answers'] = pd.to_datetime(merge['CreationDate_Answers'])
merge.dtypes
merge['CreationDate_Questions'] = pd.to_datetime(merge['CreationDate_Questions'])
merge['Time it takes'] = merge['CreationDate_Answers'] - merge['CreationDate_Questions']
sort_merge = merge.sort_values(ascending=True, by = 'Time it takes')
sort_merge
# Out:
#         Id_Answers  OwnerUserId_Answers CreationDate_Answers  ParentId  \
# 266569    10955711             279627.0  2012-06-08 20:33:54  33054229
# 266570    10955713              14343.0  2012-06-08 20:34:00  33054229
# 266571    10955754            1358283.0  2012-06-08 20:38:16  33054229
# 1493         64486               7829.0  2008-09-15 16:34:29    510348
# 6623        261008               6491.0  2008-11-04 05:47:59    508657
# 6624        261084               2140.0  2008-11-04 06:37:50    508657
# 6625        261340               6848.0  2008-11-04 09:34:25    508657
# 6626        261656              10661.0  2008-11-04 12:04:00    508657
# 6627        264562              11265.0  2008-11-05 07:33:36    508657
# 230123     9298610            1002469.0  2012-02-15 17:55:07   9385979
# 230124     9298791             779813.0  2012-02-15 18:05:45   9385979
# 230125     9298876            1212020.0  2012-02-15 18:11:45   9385979
# 549241    23537972             100297.0  2014-05-08 09:34:57  23542593
# 930779    38160717            1644198.0  2016-07-02 13:30:51  38162235
# 549242    23539243            2395542.0  2014-05-08 10:31:53  23542593
# 53237      1903764             180100.0  2009-12-14 21:54:31   1904170
# 53238      1903809             131084.0  2009-12-14 22:02:09   1904170
# 156259     5846590             131527.0  2011-05-01 05:06:53   5846818
# 156260     5846597             396811.0  2011-05-01 05:09:15   5846818
# 156261     5846609             596329.0  2011-05-01 05:11:20   5846818
# 53239      1903860               3692.0  2009-12-14 22:10:32   1904170
# 676984    28922627             391865.0  2015-03-08 03:03:44  28922597
# 870426    35965963            5396645.0  2016-03-13 03:04:15  35965882
# 676983    28922711            1737080.0  2015-03-08 03:18:55  28922563
# 237874     9652138            1161876.0  2012-03-11 03:23:59   9651970
# 954785    39015705            1773904.0  2016-08-18 10:21:52  39015704
# 486910    20892876            2387370.0  2014-01-02 22:11:09  20892875
# 713873    30301855            1075247.0  2015-05-18 11:21:28  30301854
# 891228    36709462            2800876.0  2016-04-19 05:38:00  36709461
# 971393    39596988            2751937.0  2016-09-20 14:36:51  39596987
# ...            ...                  ...                  ...       ...
# 2312      39523019            3006366.0  2016-09-16 02:41:18    101754
# 772       39251599            6742808.0  2016-08-31 13:53:20     38987
# 868       39288092            3520792.0  2016-09-02 08:47:11     42950
# 201       38891913            4972892.0  2016-08-11 09:05:38      8948
# 2555      39591208            6733259.0  2016-09-20 10:03:37    111234
# 4845      39968406            2144390.0  2016-10-10 23:42:58    191644
# 900       39356849            1209842.0  2016-09-06 19:55:29     43580
# 1184      39469420            5267848.0  2016-09-13 11:53:56     53513
# 3386      39776104             808804.0  2016-09-29 17:02:51    136097
# 716       39381275            2101337.0  2016-09-08 01:29:19     38238
# 560       39336630            1183098.0  2016-09-05 19:30:06     35538
# 3854      39925524            6815329.0  2016-10-07 20:43:57    154443
# 3387      39829692            6755093.0  2016-10-03 10:41:18    136097
# 506       39350898            1791024.0  2016-09-06 13:57:36     32899
# 4776      40120729            7031759.0  2016-10-19 01:44:36    189645
# 1185      39598495            5934465.0  2016-09-20 15:45:59     53513
# 1409      39740835             260480.0  2016-09-28 07:31:38     61151
# 97        39051901            2132157.0  2016-08-20 08:03:03      1854
# 2371      39925909            1278938.0  2016-10-07 21:15:05    104420
# 838       39638334            6505489.0  2016-09-22 11:54:05     42034
# 2258      39937878             832230.0  2016-10-08 22:11:25    100298
# 1936      39932496            5177604.0  2016-10-08 12:43:02     82831
# 3506      40118371            7038953.0  2016-10-18 21:26:53    139180
# 2082      39969619            2679465.0  2016-10-11 02:26:49     89228
# 2244      40017019              56974.0  2016-10-13 09:21:26    100003
# 773       39736284            1539655.0  2016-09-28 00:33:55     38987
# 369       39573536            4269615.0  2016-09-19 12:45:10     22676
# 1538      40076866            4380481.0  2016-10-17 00:10:09     67454
# 1307      40054478            2809027.0  2016-10-15 03:00:43     59825
# 736       39946546            5833286.0  2016-10-09 17:39:01     38601
#
#         Score_Answers                                       Body_Answers  \
# 266569             39  <p>Add a space after the <code>4</code>:</p>\n...
# 266570             84  <p>You need parens:</p>\n\n<pre><code>(4).__st...
# 266571              7  <p>actually (to increase unreadability...):</p...
# 1493              330  <p>You can use the sleep() function in the tim...
# 6623                3  <p>For numeric data, <a href="http://numpy.sci...
# 6624               18  <p>If you restrict yourself to the Python stan...
# 6625               13  <p>To create a standard python array of arrays...
# 6626               10  <p>Multidimensional arrays are a little murky....
# 6627                0  <p>Another option is to use a dictionary:</p>\...
# 230123              1  <p>If these are actually email messages, you c...
# 230124              0  <p>Just use split and then check to see if the...
# 230125              6  <p>The data is in quoted-printable encoding, t...
# 549241              2  <p>If you have read a list of lists, use <code...
# 930779              1  <p>The <code>clean_&lt;fieldname&gt;</code> me...
# 549242              0  <pre><code>#!/usr/bin/python\nimport ast\nfile...
# 53237               4  <p>something like that (lines is a list of all...
# 53238               1  <pre><code>p, wncf, nvar, nclauses, hard = lin...
# 156259              4  <p>You can just use string manipulation withou...
# 156260              3  <pre><code>&gt;&gt;&gt; import re\n&gt;&gt;&gt...
# 156261              2  <p>Yeah, it should be:</p>\n\n<pre><code>&gt;&...
# 53239               0  <p>Using regular expressions would be about th...
# 676984              1  <p>You need to change <em>owner</em> of files ...
# 870426              0  <p>OK - Simple Answer - I forgot to use</p>\n\...
# 676983             -1  <p>Let us start with building it in ascending ...
# 237874              0  <p>I think this is what you are looking for.</...
# 954785              0  <p>By applying <code>django.db.models.Sum</cod...
# 486910              0  <p>Here is my current solution to this problem...
# 713873              0  <p>The documentation refers to python dates, o...
# 891228              0  <p>The following function will get you the Acc...
# 971393              0  <p>It can be done using the copy_from() method...
# ...               ...                                                ...
# 2312                0  <p>You can use <strong>QPython</strong>:</p>\n...
# 772                 0  <p>For Python 2 :</p>\n\n<pre><code>x = {'a':1...
# 868                 1  <p>You can calculate the end date yourself. th...
# 201                 0  <p>easiest method is <a href="https://github.c...
# 2555                1  <p>To check function or method of class is cal...
# 4845                0  <h1>2016 update</h1>\n\n<p>pymssql v2.x does i...
# 900                 2  <p>In Python 3.x and webapp with url to the fi...
# 1184                0  <p>You can even try using bool() like this</p>...
# 3386                1  <p>Another consideration with respect to stati...
# 716                 0  <p>A class defines a set of instances, of cour...
# 560                 0  <p>In my case the python W3C/HTML validation p...
# 3854                0  <p>I have several test cases in a test suite a...
# 3387                0  <p><strong>Static Methods:</strong></p>\n\n<ul...
# 506                 0  <p>This solution works with <code>unittest</co...
# 4776                0  <p>probably little trick like below will do if...
# 1185                0  <p>Demo:    </p>\n\n<pre><code>tasks = ['task1...
# 1409                0  <p>Every once in a while I find myself checkin...
# 97                  1  <p>You can also use only platform module witho...
# 2371                0  <p>This way is better than the alternatives I'...
# 838                 0  <p>A tuple is a sequence of values. The values...
# 2258                0  <p>For checking cyclomatic complexity, there i...
# 1936                6  <p>Testing for files and folders with <code>os...
# 3506               -1  <p>You can use the following method to get lis...
# 2082                0  <p>Here is calling a external command and retu...
# 2244                0  <h1>Role of a metaclass's <code>__call__()</co...
# 773                 0  <p>In Python 3.5 you can use unpack <code>**</...
# 369                 2  <p>Following are the most commonly used calls ...
# 1538                0  <p>For python3 i use the <strong>io.ByteIO</st...
# 1307                1  <h2>tl;dr</h2>\n\n<p><code>for first_item in m...
# 736                 0  <p>In Django 10.\nmyproject/urls.py:\nat the b...
#
#         Id_Questions  OwnerUserId_Questions CreationDate_Questions  \
# 266569      33054229              1090079.0    2015-10-10 12:55:24
# 266570      33054229              1090079.0    2015-10-10 12:55:24
# 266571      33054229              1090079.0    2015-10-10 12:55:24
# 1493          510348                46646.0    2009-02-04 07:04:09
# 6623          508657                56376.0    2009-02-03 19:54:37
# 6624          508657                56376.0    2009-02-03 19:54:37
# 6625          508657                56376.0    2009-02-03 19:54:37
# 6626          508657                56376.0    2009-02-03 19:54:37
# 6627          508657                56376.0    2009-02-03 19:54:37
# 230123       9385979              1018129.0    2012-02-21 22:06:21
# 230124       9385979              1018129.0    2012-02-21 22:06:21
# 230125       9385979              1018129.0    2012-02-21 22:06:21
# 549241      23542593              3615736.0    2014-05-08 13:04:38
# 930779      38162235              3252642.0    2016-07-02 16:14:01
# 549242      23542593              3615736.0    2014-05-08 13:04:38
# 53237        1904170               231656.0    2009-12-14 23:09:35
# 53238        1904170               231656.0    2009-12-14 23:09:35
# 156259       5846818               732923.0    2011-05-01 06:11:28
# 156260       5846818               732923.0    2011-05-01 06:11:28
# 156261       5846818               732923.0    2011-05-01 06:11:28
# 53239        1904170               231656.0    2009-12-14 23:09:35
# 676984      28922597              3856624.0    2015-03-08 03:59:26
# 870426      35965882              5396645.0    2016-03-13 03:49:57
# 676983      28922563              4645727.0    2015-03-08 03:52:17
# 237874       9651970              1045235.0    2012-03-11 03:44:36
# 954785      39015704              1773904.0    2016-08-18 10:21:52
# 486910      20892875              2387370.0    2014-01-02 22:11:09
# 713873      30301854              1075247.0    2015-05-18 11:21:28
# 891228      36709461              2800876.0    2016-04-19 05:38:00
# 971393      39596987              2751937.0    2016-09-20 14:36:51
# ...              ...                    ...                    ...
# 2312          101754                 9951.0    2008-09-19 13:21:12
# 772            38987                 3207.0    2008-09-02 07:44:30
# 868            42950                  680.0    2008-09-04 00:54:44
# 201             8948                  145.0    2008-08-12 15:16:00
# 2555          111234                 9951.0    2008-09-21 15:34:32
# 4845          191644                13380.0    2008-10-10 14:39:01
# 900            43580                 2260.0    2008-09-04 12:07:27
# 1184           53513                 4872.0    2008-09-10 06:20:11
# 3386          136097                 4766.0    2008-09-25 21:01:57
# 716            38238                 3171.0    2008-09-01 18:16:41
# 560            35538                 3594.0    2008-08-30 01:15:32
# 3854          154443                 1476.0    2008-09-30 18:55:59
# 3387          136097                 4766.0    2008-09-25 21:01:57
# 506            32899                  720.0    2008-08-28 17:49:02
# 4776          189645                15537.0    2008-10-10 00:02:01
# 1185           53513                 4872.0    2008-09-10 06:20:11
# 1409           61151                 4883.0    2008-09-14 05:41:11
# 97              1854                  116.0    2008-08-05 03:23:18
# 2371          104420                 3399.0    2008-09-19 18:41:03
# 838            42034                  577.0    2008-09-03 16:13:06
# 2258          100298                14648.0    2008-09-19 07:40:22
# 1936           82831                15616.0    2008-09-17 12:55:00
# 3506          139180                 6527.0    2008-09-26 12:38:52
# 2082           89228                17085.0    2008-09-18 01:35:30
# 2244          100003                 9951.0    2008-09-19 06:10:46
# 773            38987                 3207.0    2008-09-02 07:44:30
# 369            22676                 2109.0    2008-08-22 15:34:13
# 1538           67454                 9812.0    2008-09-15 22:00:31
# 1307           59825                 2260.0    2008-09-12 19:58:33
# 736            38601                 2592.0    2008-09-01 23:22:55
#
#         Score_Questions                                              Title  \
# 266569               43  Accessing attributes on literals work on all t...
# 266570               43  Accessing attributes on literals work on all t...
# 266571               43  Accessing attributes on literals work on all t...
# 1493               1061             How can I make a time delay in Python?
# 6623                  8                   Multidimensional array in Python
# 6624                  8                   Multidimensional array in Python
# 6625                  8                   Multidimensional array in Python
# 6626                  8                   Multidimensional array in Python
# 6627                  8                   Multidimensional array in Python
# 230123                3                       python imaplib reading gmail
# 230124                3                       python imaplib reading gmail
# 230125                3                       python imaplib reading gmail
# 549241                1                    Creating Sublists from a "List"
# 930779                1          Django IntegrityError email is not unique
# 549242                1                    Creating Sublists from a "List"
# 53237                 2                     Python: Checking Header Format
# 53238                 2                     Python: Checking Header Format
# 156259                5                         python string manipulation
# 156260                5                         python string manipulation
# 156261                5                         python string manipulation
# 53239                 2                     Python: Checking Header Format
# 676984                0  issue with pip installing django in ubuntu ser...
# 870426                0         No error, but no data written to SQLite DB
# 676983                0                     Creating a Pattern with Python
# 237874                4  Any App Engine boilerplates available to save ...
# 954785                0  Django query to annotate number of foreign key...
# 486910                0  Using Python to communicate with a minecraft s...
# 713873                0      What does Django Date filter mean by 'Naive'?
# 891228                1                       Get AWS Account ID from Boto
# 971393                0  How to update metadata of an existing object i...
# ...                 ...                                                ...
# 2312               1360           Is there a way to run Python on Android?
# 772                1867  How to merge two Python dictionaries in a sing...
# 868                 306                Get Last Day of the Month in Python
# 201                  81                Accessing mp3 Meta-Data with Python
# 2555                170                    What is a "callable" in Python?
# 4845                  7  How do you get output parameters from a stored...
# 900                 101     How to find the mime type of a file in python?
# 1184               1615               Best way to check if a list is empty
# 3386               1583  What is the difference between @staticmethod a...
# 716                 194              What are Class methods in Python for?
# 560                  21                         Validate (X)HTML in Python
# 3854                204                           How to avoid .pyc files?
# 3387               1583  What is the difference between @staticmethod a...
# 506                 111  How to generate dynamic (parametrized) unit te...
# 4776                226      How to break out of multiple loops in Python?
# 1185               1615               Best way to check if a list is empty
# 1409                286                 Where do the Python unit tests go?
# 97                  270    How to check what OS am I running on in Python?
# 2371                271  How to generate all permutations of a list in ...
# 838                  25                        What is a tuple useful for?
# 2258                 91  How can I analyze Python code to identify prob...
# 1936               2729  How do I check whether a file exists using Pyt...
# 3506                164           listing all functions in a python module
# 2082               2312              Calling an external command in Python
# 2244               3219                     What is a metaclass in Python?
# 773                1867  How to merge two Python dictionaries in a sing...
# 369                 492   How do I download a file over HTTP using Python?
# 1538                 41  Serving dynamically generated ZIP archives in ...
# 1307                154  How to retrieve an element from a set without ...
# 736                 147      Using Django time/date widgets in custom form
#
#                                            Body_Questions        Time it takes
# 266569  <p>I have read that everything in python is an... -1219 days +07:38:30
# 266570  <p>I have read that everything in python is an... -1219 days +07:38:36
# 266571  <p>I have read that everything in python is an... -1219 days +07:42:52
# 1493    <p>I would like to know how to put a time dela...  -142 days +09:30:20
# 6623    <p>I have a little Java problem I want to tran...   -92 days +09:53:22
# 6624    <p>I have a little Java problem I want to tran...   -92 days +10:43:13
# 6625    <p>I have a little Java problem I want to tran...   -92 days +13:39:48
# 6626    <p>I have a little Java problem I want to tran...   -92 days +16:09:23
# 6627    <p>I have a little Java problem I want to tran...   -91 days +11:38:59
# 230123  <p>I am using imaplib to read gmail messages i...    -7 days +19:48:46
# 230124  <p>I am using imaplib to read gmail messages i...    -7 days +19:59:24
# 230125  <p>I am using imaplib to read gmail messages i...    -7 days +20:05:24
# 549241  <p>I have a list in a file,\nlooks like this <...    -1 days +20:30:19
# 930779  <p>I am working on my Checkout view with regul...    -1 days +21:16:50
# 549242  <p>I have a list in a file,\nlooks like this <...    -1 days +21:27:15
# 53237   <p>I'm new to python and need help with a prob...    -1 days +22:44:56
# 53238   <p>I'm new to python and need help with a prob...    -1 days +22:52:34
# 156259  <p>I have a string <code>s</code> with nested ...    -1 days +22:55:25
# 156260  <p>I have a string <code>s</code> with nested ...    -1 days +22:57:47
# 156261  <p>I have a string <code>s</code> with nested ...    -1 days +22:59:52
# 53239   <p>I'm new to python and need help with a prob...    -1 days +23:00:57
# 676984  <p>I created a virtualenv on and EC2 instance,...    -1 days +23:04:18
# 870426  <p>I have a python list called result that con...    -1 days +23:14:18
# 676983  <p>With Python editor I am trying to recreate ...    -1 days +23:26:38
# 237874  <p>Are the any projects that provide basic fea...    -1 days +23:39:23
# 954785  <p>If I had the following related models:</p>\...      0 days 00:00:00
# 486910  <p>This question was deleted when I was just a...      0 days 00:00:00
# 713873  <p>I want to use the <code>'c'</code> date for...      0 days 00:00:00
# 891228  <p>I have an AWS_ACCESS_KEY_ID and an AWS_SECR...      0 days 00:00:00
# 971393  <p>boto3 documentation does not clearly specif...      0 days 00:00:00
# ...                                                   ...                  ...
# 2312    <p>We are working on an <a href="http://en.wik...   2918 days 13:20:06
# 772     <p>I have two Python dictionaries, and I want ...   2920 days 06:08:50
# 868     <p>Is there a way using Python's standard libr...   2920 days 07:52:27
# 201     <p>What is the best way to retrieve mp3 metada...   2920 days 17:49:38
# 2555    <p>Now that it's clear <a href="http://stackov...   2920 days 18:29:05
# 4845    <p>I've googled around a bit, but maybe I didn...   2922 days 09:03:57
# 900     <p>Let's say you want to save a bunch of files...   2924 days 07:48:02
# 1184    <p>For example, if passed the following:</p>\n...   2925 days 05:33:45
# 3386    <p>What is the difference between a function d...   2925 days 20:00:54
# 716     <p>I'm teaching myself Python and my most rece...   2928 days 07:12:38
# 560     <p>What's the best way to go about validating ...   2928 days 18:14:34
# 3854    <p>Can I run the python interpreter without ge...   2929 days 01:47:58
# 3387    <p>What is the difference between a function d...   2929 days 13:39:21
# 506     <p>I have some kind of test data and want to c...   2930 days 20:08:34
# 4776    <p>Given the following code (that doesn't work...   2931 days 01:42:35
# 1185    <p>For example, if passed the following:</p>\n...   2932 days 09:25:48
# 1409    <p>If you're writing a library, or an app, whe...   2936 days 01:50:27
# 97      <p>What do I need to look at to see if I'm on ...   2937 days 04:39:45
# 2371    <p>How do you generate all the permutations of...   2940 days 02:34:02
# 838     <p>I am learning Python for a class now, and w...   2940 days 19:40:59
# 2258    <p>I have a large source repository split acro...   2941 days 14:31:03
# 1936    <p>How do I check whether a file exists, witho...   2942 days 23:48:02
# 3506    <p>I have a python module installed on my syst...   2944 days 08:48:01
# 2082    <p>How can I call an external command (as if I...   2945 days 00:51:19
# 2244    <p>What are metaclasses? What do you use them ...   2946 days 03:10:40
# 773     <p>I have two Python dictionaries, and I want ...   2947 days 16:49:25
# 369     <p>I have a small utility that I use to downlo...   2949 days 21:10:57
# 1538    <p>How to serve users a dynamically generated ...   2953 days 02:09:38
# 1307    <p>Suppose the following:</p>\n\n<pre><code>&g...   2954 days 07:02:10
# 736     <p>How can I use the nifty JavaScript date and...   2959 days 18:16:06
#
# [987122 rows x 13 columns]

# %%
sort_merge.loc[sort_merge['ParentId'] == 33054229]
# Out:
#         Id_Answers  OwnerUserId_Answers CreationDate_Answers  ParentId  \
# 266569    10955711             279627.0  2012-06-08 20:33:54  33054229
# 266570    10955713              14343.0  2012-06-08 20:34:00  33054229
# 266571    10955754            1358283.0  2012-06-08 20:38:16  33054229
# 266572    33054230            1090079.0  2015-10-10 12:55:24  33054229
#
#         Score_Answers                                       Body_Answers  \
# 266569             39  <p>Add a space after the <code>4</code>:</p>\n...
# 266570             84  <p>You need parens:</p>\n\n<pre><code>(4).__st...
# 266571              7  <p>actually (to increase unreadability...):</p...
# 266572             45  <h3>So you think you can <strike>&nbsp;dance&n...
#
#         Id_Questions  OwnerUserId_Questions CreationDate_Questions  \
# 266569      33054229              1090079.0    2015-10-10 12:55:24
# 266570      33054229              1090079.0    2015-10-10 12:55:24
# 266571      33054229              1090079.0    2015-10-10 12:55:24
# 266572      33054229              1090079.0    2015-10-10 12:55:24
#
#         Score_Questions                                              Title  \
# 266569               43  Accessing attributes on literals work on all t...
# 266570               43  Accessing attributes on literals work on all t...
# 266571               43  Accessing attributes on literals work on all t...
# 266572               43  Accessing attributes on literals work on all t...
#
#                                            Body_Questions        Time it takes
# 266569  <p>I have read that everything in python is an... -1219 days +07:38:30
# 266570  <p>I have read that everything in python is an... -1219 days +07:38:36
# 266571  <p>I have read that everything in python is an... -1219 days +07:42:52
# 266572  <p>I have read that everything in python is an...      0 days 00:00:00

# %%
#datetime_to_numeric = merge
average_time = merge[[ 'ParentId', 'Time it takes']].groupby(['ParentId']).min()
average_time.head()
# Out:
#          Time it takes
# ParentId
# 469           01:45:37
# 502           01:47:09
# 535           00:13:02
# 594           00:02:28
# 683           01:11:34

# %%
average_time.mean()
average_time_df = pd.DataFrame(average_time)
average_time_df['Time it takes'] = pd.to_numeric(average_time_df['Time it takes'])
average_time_df.dtypes
average_time_df.mean()
# Out:
# Time it takes    7.481329e+14
# dtype: float64

# %%
#average_score = merge[['Score_Questions']].groupby(['Score_Questions']).mean()

# %%
#average_score.head()

# %%
average_time_histogram = pd.DataFrame({'average_time_df': np.random.normal(size=100)})

average_time_df.describe()
average_time_df.plot(kind='hist')
pd.cut(np.array([-1.052941e+17, 3.810000e+11, 1.204000e+12, 7.945000e+12, 2.153771e+17]), 3)

range = np.arange(-1.052941e+17, 2.153771e+17, 1e+15)
plt.plot(range, norm.pdf(range,-1.052941e+17, 2.153771e+17))
#average_time_df_scatter = average_time_df.plot.kde()
