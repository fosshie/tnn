# %%
#Import the data 
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
from scipy.stats import norm
# %matplotlib notebook
import matplotlib.pyplot as plt
import statsmodels.api as sm
from statsmodels.formula.api import ols
from statsmodels.sandbox.regression.predstd import wls_prediction_std

# %%
#Read the csv files
questions_python = pd.read_csv("Resources/Questions.csv", encoding = "iso-8859-1")
answers_python = pd.read_csv("Resources/Answers.csv", encoding = 'iso-8859-1')
tags_python = pd.read_csv("Resources/Tags.csv", encoding = 'iso-8859-1')

# %%
#Clean up the Data Frames
#Since we can't fully read the Title or the Body of the text from the DF,
#atually, we don't need the Title and Body of the text 
#I just remove them to make the data frames cleaner 
#And we will be working with the clean Data Frames from now on

clean_questions_python = questions_python[['Id','OwnerUserId', 'CreationDate',
                                           'Score','Title']]
clean_answers_python = answers_python[['Id','OwnerUserId','ParentId','CreationDate',
                                       'Score']]
clean_questions_python.head()
# Out:
#     Id  OwnerUserId          CreationDate  Score  \
# 0  469        147.0  2008-08-02T15:11:16Z     21
# 1  502        147.0  2008-08-02T17:01:58Z     27
# 2  535        154.0  2008-08-02T18:43:54Z     40
# 3  594        116.0  2008-08-03T01:15:08Z     25
# 4  683        199.0  2008-08-03T13:19:16Z     28
#
#                                                Title
# 0  How can I find the full path to a font from it...
# 1            Get a preview JPEG of a PDF on Windows?
# 2  Continuous Integration System for a Python Cod...
# 3     cx_Oracle: How do I iterate over a result set?
# 4  Using 'in' to match an attribute of Python obj...

# %%
#Sort Questions by ID
sort_questions = clean_questions_python.sort_values(ascending=True, by = 'Id')
#Sort Answers by ID
sort_answers = clean_answers_python.sort_values(ascending=True, by = 'Id')
#Sort Tags by ID 
sort_tags = tags_python.sort_values(ascending=True, by = 'Id')

# %%
#Convert date into numerical value for both Questions and Answers DF 
clean_questions_python['CreationDate'] = pd.to_datetime(questions_python['CreationDate'])
clean_answers_python['CreationDate'] = pd.to_datetime(answers_python['CreationDate'])
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
#Rename the columns' names to make it looks better
sort_python_questions = sort_questions.rename(columns={'CreationDate': "Questions' Creation Date",
                                                      'OwnerUserId': "Owner's User Id"})
sort_python_answers = sort_answers.rename(columns={'CreationDate': "Answers' Creation Date",
                                                      'OwnerUserId': "Owner's User Id"})
sort_python_questions.head()
# Out:
#     Id  Owner's User Id Questions' Creation Date  Score  \
# 0  469            147.0     2008-08-02T15:11:16Z     21
# 1  502            147.0     2008-08-02T17:01:58Z     27
# 2  535            154.0     2008-08-02T18:43:54Z     40
# 3  594            116.0     2008-08-03T01:15:08Z     25
# 4  683            199.0     2008-08-03T13:19:16Z     28
#
#                                                Title
# 0  How can I find the full path to a font from it...
# 1            Get a preview JPEG of a PDF on Windows?
# 2  Continuous Integration System for a Python Cod...
# 3     cx_Oracle: How do I iterate over a result set?
# 4  Using 'in' to match an attribute of Python obj...

# %%
sort_python_answers.head()
# Out:
#     Id  Owner's User Id  ParentId Answers' Creation Date  Score
# 0  497             50.0       469   2008-08-02T16:56:53Z      4
# 1  518            153.0       469   2008-08-02T17:42:28Z      2
# 2  536            161.0       502   2008-08-02T18:49:07Z      9
# 3  538            156.0       535   2008-08-02T18:56:56Z     23
# 4  541            157.0       535   2008-08-02T19:06:40Z     20

# %%
#Merge answers and questions and tags into a single DF

merge_questions_answers = sort_python_answers.merge(sort_python_questions, left_on = 'ParentId', right_on = 'Id', suffixes = ['(Answers)' , '(Questions)'])
merge_all = sort_tags.join(merge_questions_answers)
merge_all.head()

#questions_python.dtypes
# Out:
#     Id        Tag  Id(Answers)  Owner's User Id(Answers)  ParentId  \
# 0  469     python        497.0                      50.0     469.0
# 1  469        osx        518.0                     153.0     469.0
# 2  469      fonts       3040.0                     457.0     469.0
# 3  469  photoshop     195170.0                     745.0     469.0
# 4  502     python        536.0                     161.0     502.0
#
#   Answers' Creation Date  Score(Answers)  Id(Questions)  \
# 0   2008-08-02T16:56:53Z             4.0          469.0
# 1   2008-08-02T17:42:28Z             2.0          469.0
# 2   2008-08-06T03:01:23Z            12.0          469.0
# 3   2008-10-12T07:02:40Z             1.0          469.0
# 4   2008-08-02T18:49:07Z             9.0          502.0
#
#    Owner's User Id(Questions) Questions' Creation Date  Score(Questions)  \
# 0                       147.0     2008-08-02T15:11:16Z              21.0
# 1                       147.0     2008-08-02T15:11:16Z              21.0
# 2                       147.0     2008-08-02T15:11:16Z              21.0
# 3                       147.0     2008-08-02T15:11:16Z              21.0
# 4                       147.0     2008-08-02T17:01:58Z              27.0
#
#                                                Title
# 0  How can I find the full path to a font from it...
# 1  How can I find the full path to a font from it...
# 2  How can I find the full path to a font from it...
# 3  How can I find the full path to a font from it...
# 4            Get a preview JPEG of a PDF on Windows?

# %%
#Convert Questions' and Answers' Dates to numeric values to calculate 
merge_all["Questions' Creation Date"] = pd.to_datetime(merge_all["Questions' Creation Date"])
merge_all["Answers' Creation Date"] = pd.to_datetime(merge_all["Answers' Creation Date"])
#merge.dtypes

#Create a new column called 'Time it takes'
merge_all['Time it takes'] = merge_all["Answers' Creation Date"] - merge_all["Questions' Creation Date"]
sort_merge = merge_all.sort_values(ascending=True, by = 'Time it takes')
sort_merge.head(3)
# Out:
#              Id     Tag  Id(Answers)  Owner's User Id(Answers)    ParentId  \
# 266569  9334762     xml   10955711.0                  279627.0  33054229.0
# 266570  9334762    lxml   10955713.0                   14343.0  33054229.0
# 266571  9334779  python   10955754.0                 1358283.0  33054229.0
#
#        Answers' Creation Date  Score(Answers)  Id(Questions)  \
# 266569    2012-06-08 20:33:54            39.0     33054229.0
# 266570    2012-06-08 20:34:00            84.0     33054229.0
# 266571    2012-06-08 20:38:16             7.0     33054229.0
#
#         Owner's User Id(Questions) Questions' Creation Date  Score(Questions)  \
# 266569                   1090079.0      2015-10-10 12:55:24              43.0
# 266570                   1090079.0      2015-10-10 12:55:24              43.0
# 266571                   1090079.0      2015-10-10 12:55:24              43.0
#
#                                                     Title        Time it takes
# 266569  Accessing attributes on literals work on all t... -1219 days +07:38:30
# 266570  Accessing attributes on literals work on all t... -1219 days +07:38:36
# 266571  Accessing attributes on literals work on all t... -1219 days +07:42:52

# %%
#Convert column 'Time it takes' to numerical values (in term of hours)
sort_merge["Time it takes"] =  sort_merge['Time it takes'] / np.timedelta64(1, 'h')

#Quick note: after the conversion, the column 'Time it takes' will now be of type
#float64 instead of timedelta64 so if you try to run this cell again, it will 
#give you an error, this is normal. Run cell 18 again and the problem is solved.

#Extract the cells with negative 'Time it takes'
sort_merge = sort_merge.loc[sort_merge['Time it takes'] > 0]
sort_merge

#Since it doesn't make sense for a question and answer to be created at 00:00:00,
#I make the decision to remove these entries.
#In order to make sure that I didn't make drastic change to the data table,
#I check that these instances are the outliers. Sure enough, we have 1382 out of 
#987097 total instances where question and answer creation dates are at 00:00:00
#which gives us 0.14% of our total entries. In the following code, you can test
#it yourselve. 
#non_negative_time = sort_merge.loc[sort_merge['Time it takes'] >= 0]
#zero_time = sort_merge.loc[sort_merge['Time it takes'] == 0]
#zero_time['Time it takes'].count(),non_negative_time['Time it takes'].count()
# Out:
#               Id                 Tag  Id(Answers)  Owner's User Id(Answers)  \
# 274051   9559646                list   11276096.0                  382374.0
# 269184   9413002              python   11066852.0                 1175266.0
# 272554   9517829              django   11210301.0                 1258041.0
# 3854                        1476.0      2008-09-30 18:55:59             204.0
# 3387                        4766.0      2008-09-25 21:01:57            1583.0
# 506                          720.0      2008-08-28 17:49:02             111.0
# 4776                       15537.0      2008-10-10 00:02:01             226.0
# 1185                        4872.0      2008-09-10 06:20:11            1615.0
# 1409                        4883.0      2008-09-14 05:41:11             286.0
# 97                           116.0      2008-08-05 03:23:18             270.0
# 2371                        3399.0      2008-09-19 18:41:03             271.0
# 838                          577.0      2008-09-03 16:13:06              25.0
# 2258                       14648.0      2008-09-19 07:40:22              91.0
# 1936                       15616.0      2008-09-17 12:55:00            2729.0
# 3506                        6527.0      2008-09-26 12:38:52             164.0
# 2082                       17085.0      2008-09-18 01:35:30            2312.0
# 2244                        9951.0      2008-09-19 06:10:46            3219.0
# 773                         3207.0      2008-09-02 07:44:30            1867.0
# 369                         2109.0      2008-08-22 15:34:13             492.0
# 1538                        9812.0      2008-09-15 22:00:31              41.0
# 1307                        2260.0      2008-09-12 19:58:33             154.0
# 736                         2592.0      2008-09-01 23:22:55             147.0
#
#                                                     Title  Time it takes
# 274051  Django MemoryError while Using Python Imaging ...       0.000278
# 269184  Error message "no theme named 'sphinx-theme-ok...       0.000278
# 272554    Why does zip() drop the values of my generator?       0.000278
# 267307    How to represent a jar file as a network graph?       0.000278
# 266527  Update new Django and Python 2.7.* with virtua...       0.000278
# 272608  Change collection class key of reference in as...       0.000278
# 263181                   Weighted choice short and simple       0.000278
# 270875                Does Python have an immutable list?       0.000278
# 266691                 Non-ASCII characters in Matplotlib       0.000278
# 272537                          paycheck not running test       0.000278
# 273575  python-daemon blocks ioctl call to ctypes link...       0.000278
# 267398  Qt: When nothing seems to update or repaint a ...       0.000278
# 266978  Decorator storing input in list to call every ...       0.000278
# 269132  How can I get FEniCS working in Ubuntu 12.04 w...       0.000278
# 269140  How can I get Pymacs to work in Ubuntu with EP...       0.000556
# 269181  How to use virtualenvwrapper for ckan developm...       0.000556
# 266026    How to disable or change colors from tox output       0.000556
# 275002  How do I allow a JSON response in a mechanize ...       0.000556
# 2172    How do I read selected files from a remote Zip...       0.001667
# 7944                        What does functools.wraps do?       0.001944
# 3790    How do you break into the debugger from Python...       0.002222
# 3555          How do I wrap a string in a file in Python?       0.002500
# 5017               How to check if OS is Vista in Python?       0.003056
# 716034  How do I add or remove security groups from EN...       0.003333
# 712226  How to fully emulate the behavior of static cl...       0.003333
# 5319         Python's __import__ doesn't work as expected       0.003333
# 61089   How to fix "can't adapt error" when saving bin...       0.003611
# 431690  Produce interleaving bit patterns (morton keys...       0.003611
# 574048  Python script as a cron job - how to format th...       0.003611
# 15862                How can you profile a Python script?       0.003889
# ...                                                   ...            ...
# 2312             Is there a way to run Python on Android?   70045.335000
# 772     How to merge two Python dictionaries in a sing...   70086.147222
# 868                   Get Last Day of the Month in Python   70087.874167
# 201                   Accessing mp3 Meta-Data with Python   70097.827222
# 2555                      What is a "callable" in Python?   70098.484722
# 4845    How do you get output parameters from a stored...   70137.065833
# 900        How to find the mime type of a file in python?   70183.800556
# 1184                 Best way to check if a list is empty   70205.562500
# 3386    What is the difference between @staticmethod a...   70220.015000
# 716                 What are Class methods in Python for?   70279.210556
# 560                            Validate (X)HTML in Python   70290.242778
# 3854                             How to avoid .pyc files?   70297.799444
# 3387    What is the difference between @staticmethod a...   70309.655833
# 506     How to generate dynamic (parametrized) unit te...   70340.142778
# 4776        How to break out of multiple loops in Python?   70345.709722
# 1185                 Best way to check if a list is empty   70377.430000
# 1409                   Where do the Python unit tests go?   70465.840833
# 97        How to check what OS am I running on in Python?   70492.662500
# 2371    How to generate all permutations of a list in ...   70562.567222
# 838                           What is a tuple useful for?   70579.683056
# 2258    How can I analyze Python code to identify prob...   70598.517500
# 1936    How do I check whether a file exists using Pyt...   70631.800556
# 3506             listing all functions in a python module   70664.800278
# 2082                Calling an external command in Python   70680.855278
# 2244                       What is a metaclass in Python?   70707.177778
# 773     How to merge two Python dictionaries in a sing...   70744.823611
# 369      How do I download a file over HTTP using Python?   70797.182500
# 1538    Serving dynamically generated ZIP archives in ...   70874.160556
# 1307    How to retrieve an element from a set without ...   70903.036111
# 736         Using Django time/date widgets in custom form   71034.268333
#
# [985715 rows x 13 columns]

# %%
sort_merge = sort_merge.sort_values(ascending=True, by = 'Score(Answers)')
sort_merge.head(10)
# Out:
#               Id           Tag  Id(Answers)  Owner's User Id(Answers)  \
# 119577   4468935         emacs    4320712.0                  465164.0
# 604326  18497102        python   25971173.0                  705086.0
# 77216    3105249        sqlite    2726384.0                   84270.0
# 105179   3990562        python    3780864.0                   10661.0
# 12713     753052        python     474802.0                   10661.0
# 22117    1169000  date-parsing    6407157.0                  806071.0
# 448        45228   performance      29347.0                    1815.0
# 75442    3047542      building    2654175.0                  107366.0
# 18900    1025817        python     688266.0                   10661.0
# 38952    1833563    networking    1410442.0                  101588.0
#
#           ParentId Answers' Creation Date  Score(Answers)  Id(Questions)  \
# 119577   4320679.0    2010-12-01 02:33:19           -38.0      4320679.0
# 604326  25970488.0    2014-09-22 09:50:36           -26.0     25970488.0
# 77216    2725852.0    2010-04-28 02:03:19           -24.0      2725852.0
# 105179   3780737.0    2010-09-23 17:15:19           -23.0      3780737.0
# 12713     473620.0    2009-01-23 22:06:27           -23.0       473620.0
# 22117     805066.0    2011-06-20 05:32:22           -19.0       805066.0
# 448        28796.0    2008-08-27 01:50:48           -18.0        28796.0
# 75442    2654149.0    2010-04-16 15:27:38           -17.0      2654149.0
# 18900     688245.0    2009-03-27 02:02:51           -17.0       688245.0
# 38952    1408940.0    2009-09-11 11:55:51           -16.0      1408940.0
#
#         Owner's User Id(Questions) Questions' Creation Date  Score(Questions)  \
# 119577                    525916.0      2010-12-01 02:25:39             105.0
# 604326                   2955338.0      2014-09-22 09:16:37             -44.0
# 77216                     223912.0      2010-04-27 23:25:52              42.0
# 105179                    409701.0      2010-09-23 16:58:07              11.0
# 12713                       2183.0      2009-01-23 16:48:06             185.0
# 22117                      16513.0      2009-04-30 01:52:31             271.0
# 448                         2900.0      2008-08-26 18:26:51              52.0
# 75442                     288832.0      2010-04-16 15:23:27              17.0
# 18900                      76288.0      2009-03-27 01:57:33              17.0
# 38952                     114672.0      2009-09-11 04:15:15              16.0
#
#                                                     Title  Time it takes
# 119577                       Django: Display Choice Value       0.127778
# 604326  How to collate attribute values stored as dict...       0.566389
# 77216             writing to existing workbook using xlwt       2.624167
# 105179  Add a custom button to a Django application's ...       0.286667
# 12713               How do you create a daemon in Python?       5.305833
# 22117   Call a parent class's method from child class ...   18747.664167
# 448         What refactoring tools do you use for Python?       7.399167
# 75442                   Count bits of a integer in Python       0.069722
# 18900   Is there a better Python bundle for textmate t...       0.088333
# 38952   How do I hide the field label for a HiddenInpu...       7.676667

# %%
#Perform a groupby to rank the average time based on tag.
average_time_df = sort_merge[['Tag',"Time it takes"]]
average_time_per_tag = round(average_time_df.groupby(average_time_df['Tag']).mean(),6) 
average_time_per_tag = average_time_per_tag.reset_index()
average_time_per_tag.head(5)
# Out:
#              Tag  Time it takes
# 0           .app      50.320000
# 1      .aspxauth       1.608611
# 2  .bash-profile     117.466759
# 3    .class-file      23.568056
# 4           .doc       0.063611

# %%
#Perform a value count to rank tags by popularity
merge_all['Tag'].value_counts().head(10)
# Out:
# python        607283
# django         62818
# python-2.7     34616
# pandas         26854
# python-3.x     26814
# numpy          25848
# list           18951
# matplotlib     16521
# regex          14047
# dictionary     13413
# Name: Tag, dtype: int64

# %%
popularity_per_tag = pd.DataFrame({
    'Popularity per tag': average_time_df['Tag'].value_counts()})

# %%
#Plot a bar chart for the top 30 popular tags in relation to the time it takes 
#for an answer to be posted
average_time_per_tag = average_time_per_tag.sort_values(ascending=False, by = 'Time it takes')
bar_df = popularity_per_tag.join(average_time_per_tag)
bar_df = bar_df.sort_values(ascending = False, by = 'Popularity per tag')
average_time = bar_df['Time it takes'][0:30]
bar_df = bar_df.reset_index()

tags = bar_df['index'][0:30]
plt.bar(tags,average_time, color='b', alpha=0.5, align="edge")
tick_locations = [value for value in tags]
plt.xticks(tick_locations, tags, rotation="vertical")

#Set Titles
plt.title("Average Time per Tag (Most popular)")
plt.ylabel("Average Time (hour)")
plt.xlabel("Tags")
plt.figure(figsize=(20,3))

# %%
bar_df.head()
# Out:
#         index  Popularity per tag  Time it takes
# 0      python              321923    1714.546490
# 1      django               35173    1831.969893
# 2  python-2.7               14644     649.454735
# 3       numpy               11954    1172.998791
# 4        list               10283    1508.986889

# %%
#list of the 30 Highest waiting time with respect to tags
tags
# Out:
# 0                python
# 1                django
# 2            python-2.7
# 3                 numpy
# 4                  list
# 5            python-3.x
# 6     google-app-engine
# 7                 regex
# 8            matplotlib
# 9                pandas
# 10           dictionary
# 11               string
# 12              tkinter
# 13                flask
# 14                mysql
# 15                linux
# 16               arrays
# 17                  csv
# 18       multithreading
# 19           sqlalchemy
# 20              windows
# 21                scipy
# 22                 html
# 23        django-models
# 24                 json
# 25                 pyqt
# 26                  xml
# 27                class
# 28        beautifulsoup
# 29           javascript
# Name: index, dtype: object

# %%
#Plot a bar chart for the top 30 least popular tags in relation to the time 
#it takes
bar_df = bar_df.sort_values(ascending = True, by = 'Popularity per tag')
average_time = bar_df['Time it takes'][0:30]
tags = bar_df['index'][0:30]
plt.bar(tags,average_time, color='r', alpha=0.5, align="edge")
tick_locations = [value for value in tags]
plt.xticks(tick_locations, tags, rotation="vertical")

average_time_per_tag.head(20)
#Set Titles
plt.title("Average Time per Tag (Least popular)")
plt.ylabel("Average Time (hour)")
plt.xlabel("Tags")
#plt.figure(figsize=(15,3))
plt.ylim(0,5)
# Out:
# (0, 5)

# %%
#list of the 30 lowest waiting time with respect to tags 
tags
# Out:
# 13069      asp.net-web-api2
# 10497            image-load
# 10496              textscan
# 10495             isnumeric
# 10494     dynamic-execution
# 10493              powercfg
# 10492                  uses
# 10491              fallback
# 10490             cpu-cache
# 10489           top-command
# 10488                jax-ws
# 10487           buttonclick
# 10486             multiboot
# 10498          query-tuning
# 10485               ldflags
# 10483       shared-resource
# 10482           pixelformat
# 10481                   pcx
# 10480              ocamllex
# 10479              highrise
# 10478             white-hat
# 10477          test-and-set
# 10476                 alien
# 10475          kyotocabinet
# 10474           mount-point
# 10473        github-archive
# 10472      object-reference
# 10484              blogspot
# 10471    django-inplaceedit
# 10499                  qdir
# Name: index, dtype: object

# %%
#Create a scatter plot of the population with independent variable: tag's popularity
#and dependent variable: average time it takes to answer
#In order to do this, I want to create a DF which contains both of these variables

popularity_per_tag_df = pd.DataFrame({
    'Popularity per tag': average_time_df['Tag'].value_counts()})
average_time_per_tag = round(average_time_df.groupby(average_time_df['Tag']).mean(),6)
joint_df = popularity_per_tag_df.join(average_time_per_tag)
scatter_df = joint_df[['Time it takes','Popularity per tag']]


#Scatter plot
scatter_df.plot.scatter(x = 'Popularity per tag',y= 'Time it takes',
                           marker="o", color="tomato",
                           alpha = 0.7, edgecolors = 'black')
plt.title("Average Waiting Time vs. Tags' Popularity")

#Original Hypothesis: The least commonly known languages take less time to answer
#Based on this graph, our original hypothesis failed since the least popular 
#tags are the ones with the highest waiting times.
#Note: With a highly skewed distribution, it is very difficult to work with 
#the old hypothesis, I'm working on our new hypothesis right now.I'll will 
#I'll update you guys if I made further progress.
# Out:
# Text(0.5,1,"Average Waiting Time vs. Tags' Popularity")

# %%
#Quickly check the above plot with our data frame
scatter_df = scatter_df.sort_values(ascending=False, by = 'Popularity per tag')
scatter_df = scatter_df.reset_index()

scatter_df.head()
# Out:
#         index  Time it takes  Popularity per tag
# 0      python    1714.546490              321923
# 1      django    1831.969893               35173
# 2  python-2.7     649.454735               14644
# 3       numpy    1172.998791               11954
# 4        list    1508.986889               10283

# %%
#New Hypothesis (FAILED): Higher Scores are associated with lower waiting time
#Independent Variable: Answers' Scores, Tag's popularity
#Scatter plot gives us an overview of the correlation between waiting time and answers' scores
score_time_df = sort_merge[['Tag', 'Score(Answers)','Time it takes']]
score_time_df = score_time_df.sort_values(ascending=False, by = 'Score(Answers)')

score_time_df.plot.scatter(x = 'Score(Answers)',y= 'Time it takes',
                           marker="o", color="tomato",label = "test",
                           alpha = 0.7, stacked = False, edgecolors = 'black')

plt.title("Average Waiting Time vs. Answers' Scores")
score_time_df = score_time_df.rename(columns = {'Time it takes': "time_it_takes", 
                                                'Score(Answers)': 'score_answers'})

# %%
#Since the data point highly concentrated around 500 score mark
cut_df = sort_merge.loc[(sort_merge['Score(Answers)'] > 0)]

cut_df['Tag'].value_counts()
# Out:
# python                  213121
# django                   23582
# python-2.7                9037
# numpy                     7788
# list                      6745
# python-3.x                6219
# google-app-engine         5668
# regex                     5320
# matplotlib                4730
# pandas                    4378
# dictionary                4311
# string                    4150
# tkinter                   3389
# flask                     2811
# mysql                     2719
# linux                     2633
# multithreading            2547
# windows                   2545
# arrays                    2521
# csv                       2512
# sqlalchemy                2480
# django-models             2324
# html                      2324
# scipy                     2291
# json                      2172
# xml                       2071
# pyqt                      2053
# class                     2007
# javascript                1994
# beautifulsoup             1947
#                          ...
# jplayer                      1
# netdna-api                   1
# server-monitoring            1
# schematron                   1
# erb                          1
# resque                       1
# dynamic-tables               1
# ebxml                        1
# cascadingdropdown            1
# stored-functions             1
# dispose                      1
# maven-3                      1
# link-local                   1
# nsrunloop                    1
# sijax                        1
# time-precision               1
# djvu                         1
# angular-ui-bootstrap         1
# dotnetopenauth               1
# bresenham                    1
# pinvoke                      1
# escalation                   1
# com-object                   1
# solr-query-syntax            1
# browser-extension            1
# newgem                       1
# http-post-vars               1
# nosuchfileexception          1
# pdfnet                       1
# emmet                        1
# Name: Tag, Length: 11525, dtype: int64

# %%
cut_df.head()
# Out:
#            Tag  Score(Questions)  Score(Answers)
# 105179  python              11.0           -23.0
# 12713   python             185.0           -23.0
# 18900   python              17.0           -17.0
# 4734    python              26.0           -15.0
# 31289   python              30.0           -14.0

# %%
score_time_df = cut_df[['Tag', 'Score(Answers)','Time it takes']]
score_time_df = score_time_df.sort_values(ascending=False, by = 'Score(Answers)')

score_time_df.plot.scatter(x = 'Score(Answers)',y= 'Time it takes',
                           marker="o", color="tomato",label = "test",
                           alpha = 0.7, stacked = False, edgecolors = 'black')

plt.title("Average Waiting Time vs. Answers' Scores")
score_time_df = score_time_df.rename(columns = {'Time it takes': "time_it_takes", 
                                                'Score(Answers)': 'score_answers'})

# %%
#Simple Regression on Average Waiting Time and Answer's Scores
regression_model =  ols("time_it_takes ~ score_answers", data=score_time_df).fit()
regression_model_summary = regression_model.summary()
regression_model_summary
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          time_it_takes   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     10.09
# Date:                Tue, 18 Dec 2018   Prob (F-statistic):            0.00150
# Time:                        18:39:45   Log-Likelihood:                -84915.
# No. Observations:                9037   AIC:                         1.698e+05
# Df Residuals:                    9035   BIC:                         1.698e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept       510.7752     31.059     16.445      0.000     449.893     571.657
# score_answers     5.4486      1.715      3.176      0.001       2.086       8.811
# ==============================================================================
# Omnibus:                    12036.406   Durbin-Watson:                   1.796
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          2018729.982
# Skew:                           7.743   Prob(JB):                         0.00
# Kurtosis:                      74.564   Cond. No.                         18.3
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
fig = plt.figure(figsize=(15,8))
fig = sm.graphics.plot_regress_exog(regression_model, "score_answers", fig=fig)

# %%
###New Hypothesis: Higher Question Scores are associated with higher Answers Scores
#Independent Variable: Questions' Scores, Tag's popularity
#Dependent Variable: Answers' Scores

questions_df = sort_merge[['Tag', 'Score(Questions)', 'Score(Answers)']]
questions_df = questions_df.sort_values(ascending=True, by = 'Score(Answers)')
cut_df = questions_df.loc[(questions_df['Score(Questions)'] > 0 ) & (questions_df['Score(Questions)'] <= 200)]
cut_df['Tag'].count()
# Out:
# 608090

# %%
#Scatter plot gives us an overview of the correlation between questions' and answers' scores
cut_df.plot.scatter(x = 'Score(Questions)',y= 'Score(Answers)',
                           marker="o", color="tomato",
                           alpha = 0.7, stacked = False, edgecolors = 'black')

# %%
cut_df = cut_df.rename(columns = {'Score(Questions)': "score_questions", 
                                                'Score(Answers)': 'score_answers'})
#Simple Regression on Questions' and Answer's Scores
regression_model =  ols("score_answers ~ score_questions", data=cut_df).fit()
regression_model_summary = regression_model.summary()
regression_model_summary
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          score_answers   R-squared:                       0.122
# Model:                            OLS   Adj. R-squared:                  0.122
# Method:                 Least Squares   F-statistic:                 2.332e+04
# Date:                Tue, 18 Dec 2018   Prob (F-statistic):               0.00
# Time:                        19:59:13   Log-Likelihood:            -8.2401e+05
# No. Observations:              168452   AIC:                         1.648e+06
# Df Residuals:                  168450   BIC:                         1.648e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept           5.3142      0.085     62.623      0.000       5.148       5.481
# score_questions     0.1602      0.001    152.725      0.000       0.158       0.162
# ==============================================================================
# Omnibus:                   320018.148   Durbin-Watson:                   0.232
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       1124098408.097
# Skew:                          14.502   Prob(JB):                         0.00
# Kurtosis:                     402.141   Cond. No.                         87.4
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
#filter by day, how long it has been on the internet.
fig = plt.figure(figsize=(15,8))
fig = sm.graphics.plot_regress_exog(regression_model, "score_questions", fig=fig)

# %%
#Perform the same procedure but this time on the average Questions' and Answers' Scores
new_cut_df = round(cut_df.groupby(cut_df['Tag']).mean(),6)
#Simple Regression on Average Questions' and Answer's Scores 
new_regression_model =  ols("score_answers ~ score_questions", data=new_cut_df).fit()
new_regression_model_summary = new_regression_model.summary()
new_regression_model_summary
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          score_answers   R-squared:                       0.080
# Model:                            OLS   Adj. R-squared:                  0.080
# Method:                 Least Squares   F-statistic:                     624.2
# Date:                Tue, 18 Dec 2018   Prob (F-statistic):          3.52e-132
# Time:                        19:59:20   Log-Likelihood:                -32921.
# No. Observations:                7187   AIC:                         6.585e+04
# Df Residuals:                    7185   BIC:                         6.586e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept           6.3762      0.318     20.023      0.000       5.752       7.000
# score_questions     0.1250      0.005     24.984      0.000       0.115       0.135
# ==============================================================================
# Omnibus:                    15065.211   Durbin-Watson:                   2.045
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):        111911532.348
# Skew:                          17.690   Prob(JB):                         0.00
# Kurtosis:                     613.296   Cond. No.                         72.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
fig = plt.figure(figsize=(15,8))
fig = sm.graphics.plot_regress_exog(new_regression_model, "score_questions", fig=fig)

# %%
#Multiple Regression
#Independent Variable: Quesitons' Scores, Tag's popularity
#mult_regression_model = ols("""score_answers ~ score_questions + Tag""", data=new_cut_df).fit()
#mult_regression_df =

# %%
#average_time_histogram = pd.DataFrame({'average_time_df': np.random.normal(size=100)})
#average_time_df.describe()
#pd.cut(np.array([-1.052941e+17, 3.810000e+11, 1.204000e+12, 7.945000e+12, 2.153771e+17]), 3)
#range = np.arange(-1.052941e+17, 2.153771e+17, 1e+15)
#plt.plot(range, norm.pdf(range,-1.052941e+17, 2.153771e+17))
#average_time_df_scatter = average_time_df.plot.kde()
