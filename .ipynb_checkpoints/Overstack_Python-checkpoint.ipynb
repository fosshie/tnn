# %%
#Import the data 
#1 Questions
import pandas as pd 
import numpy as np 
questions_python = pd.read_csv(r"C:\Users\khanh\Desktop\UCIRV201810DATA4\Project\Questions Python.csv",encoding='iso-8859-1')
questions_python.head()
# Out:
#     Id  OwnerUserId          CreationDate  Score  \
# 0  469        147.0  2008-08-02T15:11:16Z     21
# 1  502        147.0  2008-08-02T17:01:58Z     27
# 2  535        154.0  2008-08-02T18:43:54Z     40
# 3  594        116.0  2008-08-03T01:15:08Z     25
# 4  683        199.0  2008-08-03T13:19:16Z     28
#
#                                                Title  \
# 0  How can I find the full path to a font from it...
# 1            Get a preview JPEG of a PDF on Windows?
# 2  Continuous Integration System for a Python Cod...
# 3     cx_Oracle: How do I iterate over a result set?
# 4  Using 'in' to match an attribute of Python obj...
#
#                                                 Body
# 0  <p>I am using the Photoshop's javascript API t...
# 1  <p>I have a cross-platform (Python) applicatio...
# 2  <p>I'm starting work on a hobby project with a...
# 3  <p>There are several ways to iterate over a re...
# 4  <p>I don't remember whether I was dreaming or ...

# %%
#Sort Questions 
sort_questions = questions_python.sort_values(ascending=True, by = 'Id')
sort_questions.head()
# Out:
#     Id  OwnerUserId        CreationDate  Score  \
# 0  469        147.0 2008-08-02 15:11:16     21
# 1  502        147.0 2008-08-02 17:01:58     27
# 2  535        154.0 2008-08-02 18:43:54     40
# 3  594        116.0 2008-08-03 01:15:08     25
# 4  683        199.0 2008-08-03 13:19:16     28
#
#                                                Title  \
# 0  How can I find the full path to a font from it...
# 1            Get a preview JPEG of a PDF on Windows?
# 2  Continuous Integration System for a Python Cod...
# 3     cx_Oracle: How do I iterate over a result set?
# 4  Using 'in' to match an attribute of Python obj...
#
#                                                 Body
# 0  <p>I am using the Photoshop's javascript API t...
# 1  <p>I have a cross-platform (Python) applicatio...
# 2  <p>I'm starting work on a hobby project with a...
# 3  <p>There are several ways to iterate over a re...
# 4  <p>I don't remember whether I was dreaming or ...

# %%
#2 Ansers Python 
answers_python = pd.read_csv(r"C:\Users\khanh\Desktop\UCIRV201810DATA4\Project\Answers Python.csv", encoding = 'iso-8859-1')
answers_python.head()
# Out:
#     Id  OwnerUserId          CreationDate  ParentId  Score  \
# 0  497         50.0  2008-08-02T16:56:53Z       469      4
# 1  518        153.0  2008-08-02T17:42:28Z       469      2
# 2  536        161.0  2008-08-02T18:49:07Z       502      9
# 3  538        156.0  2008-08-02T18:56:56Z       535     23
# 4  541        157.0  2008-08-02T19:06:40Z       535     20
#
#                                                 Body
# 0  <p>open up a terminal (Applications-&gt;Utilit...
# 1  <p>I haven't been able to find anything that d...
# 2  <p>You can use ImageMagick's convert utility f...
# 3  <p>One possibility is Hudson.  It's written in...
# 4  <p>We run <a href="http://buildbot.net/trac">B...

# %%
sort_answers = answers_python.sort_values(ascending=True, by = 'Id')
sort_answers.head()
# Out:
#     Id  OwnerUserId          CreationDate  ParentId  Score  \
# 0  497         50.0  2008-08-02T16:56:53Z       469      4
# 1  518        153.0  2008-08-02T17:42:28Z       469      2
# 2  536        161.0  2008-08-02T18:49:07Z       502      9
# 3  538        156.0  2008-08-02T18:56:56Z       535     23
# 4  541        157.0  2008-08-02T19:06:40Z       535     20
#
#                                                 Body
# 0  <p>open up a terminal (Applications-&gt;Utilit...
# 1  <p>I haven't been able to find anything that d...
# 2  <p>You can use ImageMagick's convert utility f...
# 3  <p>One possibility is Hudson.  It's written in...
# 4  <p>We run <a href="http://buildbot.net/trac">B...

# %%
#3 Tags Python 
tags_python = pd.read_csv(r"C:\Users\khanh\Desktop\UCIRV201810DATA4\Project\Tags Python.csv", encoding = 'iso-8859-1')
tags_python.head()
# Out:
#     Id        Tag
# 0  469     python
# 1  469        osx
# 2  469      fonts
# 3  469  photoshop
# 4  502     python

# %%
parse the date, then groupby and mean 
pd.to_datetime[df[date]]
group them into years

# %%
#Convert date into numerical value 
questions_python['CreationDate'] = pd.to_datetime(questions_python['CreationDate'])

# %%
answers_python['CreationDate'] = pd.to_datetime(answers_python['CreationDate'])

# %%
questions_python.dtypes
questions_python.head()
# Out:
#     Id  OwnerUserId        CreationDate  Score  \
# 0  469        147.0 2008-08-02 15:11:16     21
# 1  502        147.0 2008-08-02 17:01:58     27
# 2  535        154.0 2008-08-02 18:43:54     40
# 3  594        116.0 2008-08-03 01:15:08     25
# 4  683        199.0 2008-08-03 13:19:16     28
#
#                                                Title  \
# 0  How can I find the full path to a font from it...
# 1            Get a preview JPEG of a PDF on Windows?
# 2  Continuous Integration System for a Python Cod...
# 3     cx_Oracle: How do I iterate over a result set?
# 4  Using 'in' to match an attribute of Python obj...
#
#                                                 Body
# 0  <p>I am using the Photoshop's javascript API t...
# 1  <p>I have a cross-platform (Python) applicatio...
# 2  <p>I'm starting work on a hobby project with a...
# 3  <p>There are several ways to iterate over a re...
# 4  <p>I don't remember whether I was dreaming or ...

# %%
#Merge then calculate 
python_questions_2 = sort_questions.rename(columns={'CreationDate': 'CreationQuestionsDate'})
python_questions_2.head()
# Out:
#     Id  OwnerUserId CreationQuestionsDate  Score  \
# 0  469        147.0   2008-08-02 15:11:16     21
# 1  502        147.0   2008-08-02 17:01:58     27
# 2  535        154.0   2008-08-02 18:43:54     40
# 3  594        116.0   2008-08-03 01:15:08     25
# 4  683        199.0   2008-08-03 13:19:16     28
#
#                                                Title  \
# 0  How can I find the full path to a font from it...
# 1            Get a preview JPEG of a PDF on Windows?
# 2  Continuous Integration System for a Python Cod...
# 3     cx_Oracle: How do I iterate over a result set?
# 4  Using 'in' to match an attribute of Python obj...
#
#                                                 Body
# 0  <p>I am using the Photoshop's javascript API t...
# 1  <p>I have a cross-platform (Python) applicatio...
# 2  <p>I'm starting work on a hobby project with a...
# 3  <p>There are several ways to iterate over a re...
# 4  <p>I don't remember whether I was dreaming or ...

# %%
#merge_data = pd.merge(answers_python, questions_python, on = '')
#merge_data
sort_answers['Body'].unique().shape
# Out:
# (986883,)

# %%
print(sort_answers.shape)
print(sort_answers['Id'].unique().shape)
# Out:
# (987122, 6)
# (987122,)

# %%
sort_questions['Id'].min()
# Out:
# 469

# %%
#to find library
answer_pandas = sort_answers.loc[sort_answers['Body'].str.contains("pandas"), :]

# %%
answer_pandas.shape
# Out:
# (19945, 6)

# %%
answer_matplotlib = sort_answers.loc[sort_answers['Body'].str.contains("matplotlib"), :]

# %%
answer_matplotlib.shape
# Out:
# (15131, 6)

# %%
#Merge answers and questions 
#merge_answers_questions = answers_python.join(questions_python)
merge = sort_answers.merge(sort_questions, left_on = 'ParentId', right_on = 'Id')
merge.head()

#questions_python.dtypes
# Out:
#      Id_x  OwnerUserId_x        CreationDate_x  ParentId  Score_x  \
# 0     497           50.0  2008-08-02T16:56:53Z       469        4
# 1     518          153.0  2008-08-02T17:42:28Z       469        2
# 2    3040          457.0  2008-08-06T03:01:23Z       469       12
# 3  195170          745.0  2008-10-12T07:02:40Z       469        1
# 4     536          161.0  2008-08-02T18:49:07Z       502        9
#
#                                               Body_x  Id_y  OwnerUserId_y  \
# 0  <p>open up a terminal (Applications-&gt;Utilit...   469          147.0
# 1  <p>I haven't been able to find anything that d...   469          147.0
# 2  <p>Unfortunately the only API that isn't depre...   469          147.0
# 3  <p>There must be a method in Cocoa to get a li...   469          147.0
# 4  <p>You can use ImageMagick's convert utility f...   502          147.0
#
#        CreationDate_y  Score_y  \
# 0 2008-08-02 15:11:16       21
# 1 2008-08-02 15:11:16       21
# ...

# %%
merge.dtypes
merge['CreationDate_x'] = pd.to_datetime(merge['CreationDate_x'])
merge['Time it takes'] = merge['CreationDate_x'] - merge['CreationDate_y']
sort_merge = merge.sort_values(ascending=True, by = 'Time it takes')
sort_merge.head(20)
# Out:
#             Id_x  OwnerUserId_x      CreationDate_x  ParentId  Score_x  \
# 266569  10955711       279627.0 2012-06-08 20:33:54  33054229       39
# 266570  10955713        14343.0 2012-06-08 20:34:00  33054229       84
# 266571  10955754      1358283.0 2012-06-08 20:38:16  33054229        7
# 1493       64486         7829.0 2008-09-15 16:34:29    510348      330
# 6623      261008         6491.0 2008-11-04 05:47:59    508657        3
# 6624      261084         2140.0 2008-11-04 06:37:50    508657       18
# 6625      261340         6848.0 2008-11-04 09:34:25    508657       13
# 6626      261656        10661.0 2008-11-04 12:04:00    508657       10
# 6627      264562        11265.0 2008-11-05 07:33:36    508657        0
# 230123   9298610      1002469.0 2012-02-15 17:55:07   9385979        1
# 230124   9298791       779813.0 2012-02-15 18:05:45   9385979        0
# 230125   9298876      1212020.0 2012-02-15 18:11:45   9385979        6
# ...

# %%
#datetime_to_numeric = merge
average_time = merge[['ParentId', 'Id_y', 'Time it takes']].groupby(['ParentId']).min()
average_time.head()
# Out:
#           Id_y Time it takes
# ParentId
# 469        469      01:45:37
# 502        502      01:47:09
# 535        535      00:13:02
# 594        594      00:02:28
# 683        683      01:11:34

# %%
average_time.mean()
# Out:
# Id_y                        2.28236e+07
# Time it takes    8 days 15:48:52.907050
# dtype: object
